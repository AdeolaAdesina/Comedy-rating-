# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
from scipy.stats import norm
from sklearn.preprocessing import StandardScaler
from scipy import stats
import warnings
warnings.filterwarnings('ignore')
# %matplotlib inline

# %%
df_train = pd.read_csv('train.csv')
df_test = pd.read_csv('test.csv')
submission = pd.read_csv('SampleSubmission.csv')

# %%
df_train['Comedian'] = df_train['Joke_identifier'].str.rsplit(n=2).str[0]
df_train['Location'] = df_train['Response_ID'].str.rsplit(n=2).str[1:].str.join(' ')
print(df_train)
# Out:
#        Viewers_ID          Joke_identifier                    Response_ID  \
# 0              A1   Klint De Drunk Enugu 1      A1_Klint De Drunk Enugu 1
# 1              A1   Klint De Drunk Enugu 2      A1_Klint De Drunk Enugu 2
# 2              A1      Klint De Drunk PH 1         A1_Klint De Drunk PH 1
# 3              A1      Klint De Drunk PH 2         A1_Klint De Drunk PH 2
# 4              A1   Klint De Drunk Lagos 1      A1_Klint De Drunk Lagos 1
# 5              A1   Klint De Drunk Lagos 2      A1_Klint De Drunk Lagos 2
# 6              A1   Klint De Drunk Lagos 3      A1_Klint De Drunk Lagos 3
# 7              A1  Klint De Drunk Warri 1      A1_Klint De Drunk Warri 1
# 8              A1          AliBaba Lagos 2             A1_AliBaba Lagos 2
# 9              A1       AliBaba Aso Rock 2          A1_AliBaba Aso Rock 2
# 10             A1          AliBaba Abuja 2             A1_AliBaba Abuja 2
# 11             A1             AliBaba PH 1                A1_AliBaba PH 1
# ...

# %%
df_train.head(5)
# Out:
#   Viewers_ID         Joke_identifier                Response_ID  Rating  \
# 0         A1  Klint De Drunk Enugu 1  A1_Klint De Drunk Enugu 1    0.11
# 1         A1  Klint De Drunk Enugu 2  A1_Klint De Drunk Enugu 2   -4.64
# 2         A1     Klint De Drunk PH 1     A1_Klint De Drunk PH 1   -3.39
# 3         A1     Klint De Drunk PH 2     A1_Klint De Drunk PH 2    0.44
# 4         A1  Klint De Drunk Lagos 1  A1_Klint De Drunk Lagos 1   -4.83
#
#          Comedian Location
# 0  Klint De Drunk  Enugu 1
# 1  Klint De Drunk  Enugu 2
# 2  Klint De Drunk     PH 1
# 3  Klint De Drunk     PH 2
# 4  Klint De Drunk  Lagos 1

# %%
df_test['Comedian'] = df_test['Joke_identifier'].str.rsplit(n=2).str[0]
df_test['Location'] = df_test['Response_ID'].str.rsplit(n=2).str[1:].str.join(' ')
print(df_test)
# Out:
#        Viewers_ID       Joke_identifier                 Response_ID  \
# 0              A1      Akpororo Lagos 1         A1_Akpororo Lagos 1
# 1              A1      Akpororo Abuja 1         A1_Akpororo Abuja 1
# 2              A1      Akpororo Abuja 5         A1_Akpororo Abuja 5
# 3              A1      I Go Dye Benin 1         A1_I Go Dye Benin 1
# 4              A1      I Go Dye Benin 3         A1_I Go Dye Benin 3
# 5              A1        I Go Dye Uyo 1           A1_I Go Dye Uyo 1
# 6              A1        I Go Dye Uyo 2           A1_I Go Dye Uyo 2
# 7              A1      Seyi Law Abuja 3         A1_Seyi Law Abuja 3
# 8              A1      Seyi Law Abuja 4         A1_Seyi Law Abuja 4
# 9              A1       Gordons Lagos 2          A1_Gordons Lagos 2
# 10             A1       Gordons Lagos 4          A1_Gordons Lagos 4
# 11             A1       Gordons Abuja 2          A1_Gordons Abuja 2
# 12             A1    Helen Paul Abuja 3       A1_Helen Paul Abuja 3
# ...

# %%
df_test.head(5)
# Out:
#   Viewers_ID   Joke_identifier          Response_ID  Comedian Location
# 0         A1  Akpororo Lagos 1  A1_Akpororo Lagos 1  Akpororo  Lagos 1
# 1         A1  Akpororo Abuja 1  A1_Akpororo Abuja 1  Akpororo  Abuja 1
# 2         A1  Akpororo Abuja 5  A1_Akpororo Abuja 5  Akpororo  Abuja 5
# 3         A1  I Go Dye Benin 1  A1_I Go Dye Benin 1  I Go Dye  Benin 1
# 4         A1  I Go Dye Benin 3  A1_I Go Dye Benin 3  I Go Dye  Benin 3

# %%
sns.factorplot('Location','Rating',data=df_train)

# %%
sns.factorplot('Comedian','Rating',data=df_train)

# %%
features_train = df_train[['Comedian', 'Location']]
features_test = df_test[['Comedian', 'Location']]

# %%
target = df_train['Rating']

# %%
from sklearn.ensemble import RandomForestRegressor

# %%
rf = RandomForestRegressor(n_estimators = 100, random_state = 42)
rf.fit(features_train, target)
